# %%
import quandl
import os

import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.base import MIMEBase
from email import encoders

# %%
user = os.environ.get('gmail_user') 
password = os.environ.get("gmail_password")
content = "demo mail send"

server = smtplib.SMTP('smtp.gmail.com',587)

server.ehlo()
server.starttls()#establish a secure connection

server.login(user, password)

server.sendmail(user,"arpanbhunia9775859976@gmail.com",content)
server.close()

# %%
data = quandl.get("BSE/BOM539397", authtoken="798zMYTxzZq9RGBX1T--")

# %%
data.head()
# Out:
#              Open   High    Low  Close    WAP  No. of Shares  No. of Trades  \
# Date
# 2018-02-26  11.62  11.62  11.62  11.62  11.62      5000000.0            9.0
# 2018-11-20  12.78  12.78  10.46  10.46  10.69          100.0            3.0
# 2018-11-21   9.42   9.42   9.42   9.42   9.42          100.0            1.0
# 2018-11-22   8.50   8.50   8.50   8.50   8.50          100.0            1.0
# 2018-11-26   8.03   8.50   8.01   8.50   8.05       104700.0           18.0
#
#             Total Turnover  Deliverable Quantity  % Deli. Qty to Traded Qty  \
# Date
# 2018-02-26      58100000.0             5000000.0                     100.00
# 2018-11-20          1069.0                 100.0                     100.00
# 2018-11-21           942.0                 100.0                     100.00
# 2018-11-22           850.0                 100.0                     100.00
# 2018-11-26        842452.0               99700.0                      95.22
#
#             Spread H-L  Spread C-O
# ...

# %%
data.to_csv("C:/Users/Administrator/Desktop/auto_mail_trigger/BSE_Stock.csv")

# %%
user = os.environ.get('gmail_user') 
password = os.environ.get("gmail_password")

try:
    msg = MIMEMultipart()
    msg["From"] = user
    msg["To"] = "arpanbhunia9775859976@gmail.com"
    msg["Subject"] = "Python"

    body = "Hi there, I am sending this from python"
    msg.attach(MIMEText(body, "plain"))

    filename = "BSE_Stock.csv"
    attachment = open(filename,"rb")

    part = MIMEBase("application","octet-stream")
    part.set_payload(attachment.read())

    encoders.encode_base64(part)
    part.add_header('Content-Disposition',"attachment;filename = "+filename)

    #attaching email to the email
    msg.attach(part)
    text = msg.as_string()
    server = smtplib.SMTP('smtp.gmail.com',587)
    server.ehlo()
    server.starttls()
    server.login(user,password)
    server.sendmail(gmail_user,"arpanbhunia9775859976@gmail.com",text)
    server.close()
except:
    print("Something went wrong.......")
